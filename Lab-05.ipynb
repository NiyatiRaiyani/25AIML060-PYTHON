# %% [markdown]
# // 25AIML060 //
# NIYATI RAIYANI //
# AIUC202_DATA ANALYSIS WITH PYTHON //
# CSPIT-AIML //
# BATCH-C //

# %% [markdown]
# Date and time

# %%
from datetime import datetime
dt = datetime.now()
dt.strftime("%m/%d/%y %H%M")
# Out:
# '07/22/26 1546'

# %%
from datetime import datetime

dt = datetime.strptime('20210323 143025', '%Y%m%d %H%M%S')
print(dt)
# Out:
# 2021-03-23 14:30:25

# %%
dt2 = datetime(2026, 4, 11, 21, 30)
delta = dt2 - dt
delta
# Out:
# datetime.timedelta(days=1845, seconds=25175)

# %%
type(delta)
# Out:
# datetime.timedelta

# %%
dt
# Out:
# datetime.datetime(2021, 3, 23, 14, 30, 25)

# %%
dt + delta
# Out:
# datetime.datetime(2026, 4, 11, 21, 30)

# %%
from datetime import datetime
dt = datetime.now()
dt.strftime("%d/%m/%Y  %U  %H : %M : %S")
# Out:
# '23/07/2026  29  09 : 21 : 30'

# %%
dt.strftime('%W')
# Out:
# '29'

# %%
dt.strftime('%u')
# Out:
# '4'

# %%
dt.strftime('%w')
# Out:
# '4'

# %%
dt.strftime('%U')
# Out:
# '29'

# %%
dt.strftime('%F')
# Out:
# '2026-07-23'

# %%
dt.strftime('%S')
# Out:
# '30'

# %%
dt.strftime('%M')
# Out:
# '21'

# %%
dt.strftime('%I')
# Out:
# '09'

# %%
dt.strftime('%d')
# Out:
# '23'

# %%
dt.strftime('%F')
# Out:
# '2026-07-23'

# %%
dt.strftime('%D')
# Out:
# '07/23/26'

# %% [markdown]
# Control Flow

# %% [markdown]
# Branching Programs

# %%
x = 41
if  x % 2 == 0 :
   print("Even")
else :
   print("Odd")
print("Done with Condition")
# Out:
# Odd
# Done with Condition

# %%
x=int(input("Enter Integer Number:"))
if x%2==0:
    if x%3==0:
        print("Divide by both 2 and 3.")
    else:
        print("Divide by 2 and not by 3.")
elif x%3==0:
    print("Divide by 3 and not by 2.")
else:
    print("Not divide by 2 and 3.")
# Out:
# Divide by both 2 and 3.

# %%
x= int(input("Enter First Number:"))
y= int(input("Enter Second Number:"))
z=int(input("Enter the third number:"))
if x<y and x<z:
    print(f"{x} is minimum.")
elif y<z:
    print(f"{y} is minimum.")
else:
    print(f"{z} is minimum.")
# Out:
# -90 is minimum.
