# %% [markdown]
# // 25AIML060 //
# NIYATI RAIYANI //
# AIUC202_DATA ANALYSIS WITH PYTHON //
# CSPIT-AIML //
# BATCH-C //

# %% [markdown]
# Date and time

# %%
from datetime import datetime
dt = datetime.now()
dt.strftime("%m/%d/%y %H%M")

# %%
dt = datetime

# %%
dt.day

# %%
dt.time

# %%
from datetime import datetime
datetime.strptime('20210323' , '%Y%m%d')
