# %% [markdown]
# **// 25AIML060 //
# NIYATI RAIYANI //
# AIUC202_DATA ANALYSIS WITH PYTHON //
# CSPIT-AIML //
# BATCH-C // **

# %%
import pandas as pd

# %%
s = pd.Series([12,-4,7,9])
print(s)
# Out:
# 0    12
# 1    -4
# 2     7
# 3     9
# dtype: int64

# %%
s = pd.Series([12,-5,4,7,9], index=['a','b','c','d','e'])
print(s)
# Out:
# a    12
# b    -5
# c     4
# d     7
# e     9
# dtype: int64

# %%
s.values
# Out:
# array([12, -5,  4,  7,  9])

# %%
s.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='str')

# %%
s['c']
# Out:
# np.int64(4)

# %%
s[0:2]
# Out:
# a    12
# b    -5
# dtype: int64

# %%
s[1] = 0 
s
# Out:
# a    12
# b    -5
# c     4
# d     7
# e     9
# 1     0
# dtype: int64

# %%
import numpy as np
arr = np.array([1,2,3,4,5])
s3 = pd.Series(arr)
s3
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s4 = pd.Series(s)
s4
# Out:
# a    12
# b    -5
# c     4
# d     7
# e     9
# 1     0
# dtype: int64

# %%
s3
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
arr[2] = -2
s3 = pd.Series(arr)
s3
# Out:
# 0    1
# 1    2
# 2   -2
# 3    4
# 4    5
# dtype: int64

# %%
import numpy as np
import pandas as pd

marks = pd. Series([12, 45, 87, 89 , 90, 78, 56, 84, 23, 91])    
s = pd.Series(marks)
s[s>80]
# Out:
# 2    87
# 3    89
# 4    90
# 7    84
# 9    91
# dtype: int64

# %%
marks = pd. Series([12, 45, 87, 89 , 90, 78, 56, 84, 23, 91] , index=['a','b','c','d','e','f','g','h','i','j'])
s = pd.Series(marks)
s
# Out:
# a    12
# b    45
# c    87
# d    89
# e    90
# f    78
# g    56
# h    84
# i    23
# j    91
# dtype: int64

# %%
np.log(s)
# Out:
# 0    2.484907
# 1    3.806662
# 2    4.465908
# 3    4.488636
# 4    4.499810
# 5    4.356709
# 6    4.025352
# 7    4.430817
# 8    3.135494
# 9    4.510860
# dtype: float64

# %%
serd =pd.Series([1,0,2,1,2,3,5], index=['white','black','red','blue','green','yellow','orange'])
serd
# Out:
# white     1
# black     0
# red       2
# blue      1
# green     2
# yellow    3
# orange    5
# dtype: int64

# %%
serd.unique()
# Out:
# array([1, 0, 2, 3, 5])

# %%
serd.value_counts()
# Out:
# 1    2
# 2    2
# 0    1
# 3    1
# 5    1
# Name: count, dtype: int64

# %%
serd.isin([0,3])
# Out:
# white     False
# black      True
# red       False
# blue      False
# green     False
# yellow     True
# orange    False
# dtype: bool

# %%
serd.isin([0,3,1])
# Out:
# white      True
# black      True
# red       False
# blue       True
# green     False
# yellow     True
# orange    False
# dtype: bool

# %%
import pandas as pd
import numpy as np
s2 = pd.Series([5, 3, np.nan, 2, np.nan, 1])
print(s2.isnull())
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# dtype: bool

# %%
s2.isnull().sum()
# Out:
# np.int64(2)

# %%
s2.notnull().sum()
# Out:
# np.int64(4)

# %%
import pandas as pd
mydict ={'red':2000,'blue':1000,'green':3000,'yellow':5000,'black':4000}
mySeries = pd.Series(mydict)
mySeries
# Out:
# red       2000
# blue      1000
# green     3000
# yellow    5000
# black     4000
# dtype: int64

# %%
import pandas as pd
colors = {'red','blue','green','white','black','yellow'}
mySeries = pd.Series(mydict,index=colors)
mySeries
# Out:
# red       2000.0
# yellow    5000.0
# black     4000.0
# white        NaN
# blue      1000.0
# green     3000.0
# dtype: float64

# %%
mydic2={'red':2000,'blue':1000,'green':3000,'yellow':5000,'black':4000,'white':6000}
mySeries2 = pd.Series(mydic2,index=colors)  
mySeries = mySeries2
mySeries
# Out:
# red       2000
# yellow    5000
# black     4000
# white     6000
# blue      1000
# green     3000
# dtype: int64
