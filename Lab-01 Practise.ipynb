# %%
print("Hello world!")
# Out:
# Hello world!

# %%
print("'python class'")
# Out:
# 'python class'

# %%
print("Sam's class")
# Out:
# Sam's class

# %%
print("'Sam's class'")
# Out:
# 'Sam's class'

# %% [markdown]
# Raw String

# %%
print(r'c:\Users\Sam\Desktop\python class')
# Out:
# c:\Users\Sam\Desktop\python class

# %%
print('''
hello sir 
good morning
i am student of python class
''')
# Out:
# hello sir
# good morning
# i am student of python class

# %%
print('''
hello sir,\
good morning,\
i am student of python class,\
''')
# Out:
# hello sir,good morning,i am student of python class,

# %% [markdown]
# String Concatation

# %%
age = input("age: ")
"Your age is " + age
# Out:
# 'Your age is 15'

# %%
'5'+'5'
# Out:
# '55'

# %%
print(3 * 'A car \n' + 5 * 'A truck \n')
# Out:
# A car
# A car
# A car
# A truck
# A truck
# A truck
# A truck
# A truck

# %%
print("Sammy is {} and {} boy. He loves to {} games {}".format('a good', 'a naughty', 'play', 'very much'))
# Out:
# Sammy is a good and a naughty boy. He loves to play games very much

# %%
print("Sammy completed {0:.10f} percent of assignment".format(75.1234589))
# Out:
# Sammy completed 75.1234589000 percent of assignment

# %%
print("Sammy completed {0:0.0f} percent of assignment".format(75.1234589))
# Out:
# Sammy completed 75 percent of assignment

# %%
a = 5
b = 15
c = a+b
print("addition of " +str(b)+"is"+satr(c))
# Out:
# addition of 15is20
