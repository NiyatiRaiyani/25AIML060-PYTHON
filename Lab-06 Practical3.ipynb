# %% [markdown]
# // 25AIML060 //
# NIYATI RAIYANI //
# AIUC202_DATA ANALYSIS WITH PYTHON //
# CSPIT-AIML //
# BATCH-C //

# %% [markdown]
# Python- Built in List Functions

# %%
fish_list=['Bowfin','Cod','Hearing','Ray','Salmon','Tuna']

# %%
fish_list
# Out:
# ['Bowfin', 'Cod', 'Hearing', 'Ray', 'Salmon', 'Tuna']

# %% [markdown]
# list.append()
# list.append(x)

# %%
fish_list.append('Wahoo')

# %%
fish_list
# Out:
# ['Bowfin', 'Cod', 'Hearing', 'Ray', 'Salmon', 'Tuna', 'Wahoo']

# %% [markdown]
# list.insert()
# list.insert(i,x)

# %%
fish_list.insert(5,'Sunfish')

# %%
fish_list
# Out:
# ['Bowfin', 'Cod', 'Hearing', 'Ray', 'Salmon', 'Sunfish', 'Tuna', 'Wahoo']

# %% [markdown]
# list.extend()

# %%
fish_w_list=['walleye','Weakfish','Weakfish','Whiting']

# %%
fish_list.extend(fish_w_list)

# %%
fish_w_list
# Out:
# ['walleye', 'Weakfish', 'Weakfish', 'Whiting']

# %% [markdown]
# list.remove()

# %%
fish_list.remove('Cod')

# %%
fish_list
# Out:
# ['Bowfin',
#  'Hearing',
#  'Ray',
#  'Salmon',
#  'Sunfish',
#  'Tuna',
#  'Wahoo',
#  'walleye',
#  'Weakfish',
#  'Weakfish',
#  'Whiting']

# %% [markdown]
# list.pop()

# %%
pop_fish=fish_list.pop(5)

# %%
pop_fish
# Out:
# 'Tuna'

# %%
fish_list
# Out:
# ['Bowfin',
#  'Hearing',
#  'Ray',
#  'Salmon',
#  'Sunfish',
#  'Wahoo',
#  'walleye',
#  'Weakfish',
#  'Weakfish',
#  'Whiting']

# %% [markdown]
# list.index()

# %%
fish_list.index('Ray')
# Out:
# 2

# %%
fish_list.index('Tuna')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 fish_list.index('Tuna')
#
# ValueError: list.index(x): x not in list

# %% [markdown]
# list.copy()

# %%
fish_list2 = fish_list

# %%
fish_list2
# Out:
# ['Bowfin',
#  'Hearing',
#  'Ray',
#  'Salmon',
#  'Sunfish',
#  'Wahoo',
#  'walleye',
#  'Weakfish',
#  'Weakfish',
#  'Whiting']

# %%
fish_list2.append('Tuna')
print(fish_list2)
print(fish_list)
# Out:
# ['Bowfin', 'Hearing', 'Ray', 'Salmon', 'Sunfish', 'Wahoo', 'walleye', 'Weakfish', 'Weakfish', 'Whiting', 'Tuna', 'Tuna', 'Tuna']
# ['Bowfin', 'Hearing', 'Ray', 'Salmon', 'Sunfish', 'Wahoo', 'walleye', 'Weakfish', 'Weakfish', 'Whiting', 'Tuna', 'Tuna', 'Tuna']

# %% [markdown]
# list.reverse()

# %%
print(fish_list)
# Out:
# ['Bowfin', 'Hearing', 'Ray', 'Salmon', 'Sunfish', 'Wahoo', 'walleye', 'Weakfish', 'Weakfish', 'Whiting', 'Tuna', 'Tuna', 'Tuna']

# %%
fish_list.reverse()
print(fish_list)
# Out:
# ['Tuna', 'Tuna', 'Tuna', 'Whiting', 'Weakfish', 'Weakfish', 'walleye', 'Wahoo', 'Sunfish', 'Salmon', 'Ray', 'Hearing', 'Bowfin']

# %%
fish_list = fish_list + ['Cod' , 'Cod']
fish_list
# Out:
# ['Tuna',
#  'Tuna',
#  'Tuna',
#  'Whiting',
#  'Weakfish',
#  'Weakfish',
#  'walleye',
#  'Wahoo',
#  'Sunfish',
#  'Salmon',
#  'Ray',
#  'Hearing',
#  'Bowfin',
#  'Cod',
#  'Cod']

# %% [markdown]
# list.cont()

# %%
fish_list.count('Cod')
# Out:
# 2

# %%
fish_age=[1,2,3,5,1,2,4,8,6]

# %%
fish_age.count(1)
# Out:
# 2

# %%
fish_age.count(2)
# Out:
# 2

# %% [markdown]
# list.sort()

# %%
fish_age
# Out:
# [1, 2, 3, 5, 1, 2, 4, 8, 6]

# %%
fish_age.sort(reverse=True)

# %%
fish_age
# Out:
# [8, 6, 5, 4, 3, 2, 2, 1, 1]

# %%
fish_age.sort(reverse=False)

# %%
fish_age
# Out:
# [1, 1, 2, 2, 3, 4, 5, 6, 8]

# %%
fish_agecopy = fish_age.copy()

# %%
fish_agecopy.sort()

# %%
fish_age
# Out:
# [8, 6, 5, 4, 3, 2, 2, 1, 1]

# %%
fish_agecopy
# Out:
# [1, 1, 2, 2, 3, 4, 5, 6, 8]

# %% [markdown]
# list.clear()

# %%
fish_age.clear()

# %%
fish_age
# Out:
# []

# %%
fish_list
# Out:
# ['Tuna',
#  'Tuna',
#  'Tuna',
#  'Whiting',
#  'Weakfish',
#  'Weakfish',
#  'walleye',
#  'Wahoo',
#  'Sunfish',
#  'Salmon',
#  'Ray',
#  'Hearing',
#  'Bowfin',
#  'Cod',
#  'Cod']

# %% [markdown]
# Built in functions

# %% [markdown]
# Isinstance()

# %%
test_int = 5
test_list = [1,2,3]
print("Is text_int integer? :" , (isinstance(test_int,int)))
print("Is text_int string? :" + str(isinstance(test_int,str)))
print("Is text_int integer? :" + str(isinstance(test_list,int)))
print("Is text_int list? :" + str(isinstance(test_list,list)))
# Out:
# Is text_int integer? : True
# Is text_int string? :False
# Is text_int integer? :False
# Is text_int list? :True

# %%
isinstance(test_list,(int,set))
# Out:
# False

# %% [markdown]
# Enumerate()

# %%
x = ('apple' , 'banana' ,'chery')
a = "geek"
y = enumerate(x)
z = enumerate(a)

print("Return type:" ,type(y))
print(enumerate(x))
# Out:
# Return type: <class 'enumerate'>
# ...

# %%
print(list(enumerate(x)))
print(list(z))
# Out:
# [(0, 'apple'), (1, 'banana'), (2, 'chery')]
# [(0, 'g'), (1, 'e'), (2, 'e'), (3, 'k')]

# %%
l1 = ["eat", "sleep","repeat"]
for ele in enumerate(l1):
    print(ele)
for count,ele in enumerate(l1,100):
    print(count,ele)
for count,ele in enumerate(l1):
    print(count)
    print(ele)
# Out:
# (0, 'eat')
# (1, 'sleep')
# (2, 'repeat')
# 100 eat
# 101 sleep
# 102 repeat
# 0
# eat
# 1
# sleep
# 2
# repeat
