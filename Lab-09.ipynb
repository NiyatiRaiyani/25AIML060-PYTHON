# %% [markdown]
# **// 25AIML060 //
# NIYATI RAIYANI //
# AIUC202_DATA ANALYSIS WITH PYTHON //
# CSPIT-AIML //
# BATCH-C // **

# %% [markdown]
# **Unpacking Tuple**

# %%
tuple = (5,6,7)
a,b,c = tuple

# %%
c
# Out:
# 7

# %%
tuple = 1,2,(3,4)
p,q,(r,s) = tuple

# %%
s
# Out:
# 4
