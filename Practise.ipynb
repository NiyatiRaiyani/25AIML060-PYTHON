# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# **Variables**

# %%
name = " Niyati "
age = 18
print("name")
# Out:
# name

# %%
name = "Niyati"
age =  18
print(name)
print(age)
# Out:
# Niyati
# 18

# %%
name = "Niyati"
age =  18
name = "Vishva"
age = 19
print(name)
print(age)
# Out:
# Vishva
# 19

# %%
name = "Niyati"
age =  15

name = "Vishva"
age = 19.0

is_adult = True

print(name)
print(age)
print(is_adult)
# Out:
# Vishva
# 19.0
# True

# %% [markdown]
# **Input**

# %%
input("What is your name? ")
# Out:
# 'Niyati'

# %%
name = input("What is your name? ")
print(name)
# Out:
# Niyati

# %% [markdown]
# **Concatation**

# %%
name = input("What is your name? ")
print("Hello, " + name + "!")
# Out:
# Hello, Niyati!

# %% [markdown]
# **Type Conversion**
#
# int()
# float()
# str()
# bool()

# %%
old_age = input("enter your old age: ")
new_age = old_age + 2
print(new_age)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 old_age = input("enter your old age: ")
# ----> 2 new_age = old_age + 2
#       3 print(new_age)
#
# TypeError: can only concatenate str (not "int") to str

# %%
old_age = input("enter your old age: ")
new_age = int(old_age) + 2
print(new_age)
# Out:
# 18

# %%
num = 18
print(float(num))
# Out:
# 18.0

# %%
first = input("Enter your first number: ")
second = input("Enter your second number: ")
sum = first + second
print(sum)
# Out:
# 23

# %%
first = input("Enter your first number: ")
second = input("Enter your second number: ")
sum = int(first) + int(second)
print("The sum is: " + sum)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 4
#       1 first = input("Enter your first number: ")
#       2 second = input("Enter your second number: ")
#       3 sum = int(first) + int(second)
# ----> 4 print("The sum is: " + sum)
#
# TypeError: can only concatenate str (not "int") to str

# %%
first = input("Enter your first number: ")
second = input("Enter your second number: ")
sum = int(first) + int(second)
print("The sum is: " + str(sum))
# Out:
# The sum is: 5

# %%
name = "Tony Strark"
name.upper()
print(name.upper())

name.lower()
print(name.lower())
# Out:
# TONY STRARK
# tony strark

# %%
print(name.find('S'))
# Out:
# 5

# %%
print(name.find('s'))
# Out:
# -1

# %%
print(name.find('strark'))
# Out:
# -1

# %%
print(name.find('Strark'))
# Out:
# 5

# %%
print(name.replace("Tony Strark" , "Ironman"))
# Out:
# Ironman

# %%
print(name)
# Out:
# Tony Strark

# %%
print(name.replace("Strark" , "Ironman"))
# Out:
# Tony Ironman

# %%
print(name.replace("T" , "H"))
# Out:
# Hony Strark

# %%
print(("T" in name))
# Out:
# True

# %%
print(("m" in name))
# Out:
# False

# %%
print(("Ironman" in name))
# Out:
# False

# %%
print(("Strark" in name))
# Out:
# True

# %% [markdown]
# **Arithmetic Operator**

# %%
print(5 + 2)
# Out:
# 7

# %%
print(5 - 2)
# Out:
# 3

# %%
print(5 * 2)
# Out:
# 10

# %%
print(5 / 2)
# Out:
# 2.5

# %%
print(5 // 2)
# Out:
# 2

# %%
print(5 % 2)
# Out:
# 1

# %%
print(5 ** 2)
# Out:
# 25

# %% [markdown]
# **Shortcuts**

# %%
i = 5
i = i + 2

print(i)
# Out:
# 7

# %%
i = 5
i += 2
print(i)
# Out:
# 7

# %% [markdown]
# **Oprator Precedence**

# %%
result =  2 + 3 * 5
print(result)
# Out:
# 17

# %%
result =  2 + 3 / 5
print(result)
# Out:
# 2.6

# %% [markdown]
# **Comments**

# %%
# here is a comment 

#taking input 

#calculating the sum of two numbers

# %% [markdown]
# **Comaparission Operator**

# %%
print(3<2)
# Out:
# False

# %%
print(3<=2)
# Out:
# False

# %%
print(3>2)
# Out:
# True

# %%
print(3>=2)
# Out:
# True

# %%
print(3 == 2)
# Out:
# False

# %%
print(3 == 3)
# Out:
# True

# %% [markdown]
# != is reverse print thy

# %%
print(3 != 3)
# Out:
# False

# %%
print(3 != 2)
# Out:
# True

# %% [markdown]
# **Logical Operator**

# %%
print(2>3 or 2>1)
# Out:
# True

# %%
print(2>3 and 7>6)
# Out:
# False

# %%
print(4>3 and 2>1)
# Out:
# True

# %%
print(not 2>3)
# Out:
# True

# %%
print(not 4>3)
# Out:
# False

# %% [markdown]
# **If else statements**

# %%
age = 19
if age >= 18:
    print("You are an adult.")
    print("You can vote.")
print("Thank you!")
# Out:
# You are an adult.
# You can vote.
# Thank you!

# %%
age = 15
if age >= 18:
    print("You are an adult.")
    print("You can vote.")
print("Thank you!")
# Out:
# Thank you!

# %%
age = 3
if age >= 18:
    print("You are an adult.")
    print("You can vote.")
elif age < 18 and age > 3:
    print("You are a teenager.")
else:
    print("You are a child.")
print("Thank you!")
# Out:
# You are a child.
# Thank you!
