# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# Variables

# %%
name = " Niyati "
age = 18
print("name")
# Out:
# name

# %%
name = "Niyati"
age =  18
print(name)
print(age)
# Out:
# Niyati
# 18

# %%
name = "Niyati"
age =  18
name = "Vishva"
age = 19
print(name)
print(age)
# Out:
# Vishva
# 19

# %%
name = "Niyati"
age =  15

name = "Vishva"
age = 19.0

is_adult = True

print(name)
print(age)
print(is_adult)
# Out:
# Vishva
# 19.0
# True

# %% [markdown]
# Input
