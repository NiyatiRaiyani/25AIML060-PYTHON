# %% [markdown]
# Intoduction to Python - Numbers

# %% [markdown]
# Numbers

# %% [markdown]
# Important operator
# x ** y  Power

# %%
2+2
# Out:
# 4

# %%
50 - 45
# Out:
# 5

# %%
+10
# Out:
# 10

# %%
2*3
# Out:
# 6

# %%
-41
# Out:
# -41

# %%
50-5*4
# Out:
# 30

# %%
14/19
# Out:
# 0.7368421052631579

# %%
19 /3
# Out:
# 6.333333333333333

# %%
19//3
# Out:
# 6

# %%
19%3
# Out:
# 1

# %%
2 ** 3
# Out:
# 8
