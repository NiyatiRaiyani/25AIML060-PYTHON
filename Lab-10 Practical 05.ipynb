# %% [markdown]
# **// 25AIML060 //
# NIYATI RAIYANI //
# AIUC202_DATA ANALYSIS WITH PYTHON //
# CSPIT-AIML //
# BATCH-C // **

# %% [markdown]
# **Error Handling**

# %%
import pandas as pd
import numpy as np
try:
    df = pd.read_csv("read.csv")
    
except:
    print("Not found. Please check the file path.")
else:
    print(df)
finally:
    print("Execution completed.")
# Out:
#     Number
# 0      1.0
# 1      2.0
# 2      3.0
# 3      4.0
# 4      5.0
# 5      6.0
# 6      7.0
# 7      8.0
# 8      9.0
# 9     10.0
# 10    11.0
# 11    12.0
# 12    13.0
# 13    14.0
# 14    15.0
# 15    16.0
# 16    17.0
# 17    18.0
# 18    19.0
# 19    20.0
# Execution completed.

# %%
#1.Division with Error Handling
try:
    num1=int(input("Enter the value of num1:"))
    num2=int(input("Enter the value of num2:"))
    result=num1/num2
    #except
    #print("Division by zero is not allowed.")
except ZeroDivisionError:
    print("Division by zero is not allowed.")
except ValueError: 
    print("Invalid input! Please enter numeric values.")
else:
    print("The result of division is:", result)
# Out:
# The result of division is: 0.5

# %%
my_list = [10,20,30,40,50]
my_list[6]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 my_list = [10,20,30,40,50]
# ----> 2 my_list[6]
#
# IndexError: list index out of range

# %%
# 2.Index Error in list Access
my_list = [10,20,30,40,50]
try:
    index = int(input("Enter an index to access(0-4):"))
    print("Value:",my_list[index])
except IndexError:
    print("Index out of range.")
# Out:
# Value: 30

# %%
# 3. File Reading with FilenotFoundError
filename = input("Enter file name to open: ")

try:
    with open(filename, 'r') as file:
    content = file.read()
    print(filename)
    print(content)
except FileNotFoundError:
    print("file not found.please check the file path")
# Out:
#   Cell In[5], line 6
#     content = file.read()
#     ^
# IndentationError: expected an indented block after 'with' statement on line 5

# %%
#4.Using Finally Block
try:
    number=int(input("Enter a number:"))
    result=10/number
except ZeroDivisionError:
    print("Division by zero is not allowed.")
except ValueError:
    print("Invalid input! Please enter a numeric value.")
else:
    print("The result of division is:", result)
finally:
    print("Execution completed.")
# Out:
# The result of division is: 0.8333333333333334
# Execution completed.

# %%
#5.Handling Multiple Errors in One Block
try:
    num1=int(input("Enter the value of num1:"))
    num2=int(input("Enter the value of num2:"))
    print("Result:",num1/num2)
except (ZeroDivisionError, ValueError) as e:
    print("Error occurred:", e)
# Out:
# Result: 0.5

# %%
# 6. Create a custom Exception
class underageError(Exception):
    pass
age = int(input("Enter yor Age :"))
try:
    if age < 18:
        raise underageErro("You must be age")
    else:
        print("Access grated")

# %%
# 7. TypeError Handling in function
def add_numbers(x,y):
    if not isstance(x,(int,float)) or not isinstance(y,(int,float)):
        raise TypeError("Both Arguments must be numbers.")
    return x+y
try:
    print(add_numbers("10",5))
except TypeError as e:
    print("Error :",e)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 8
#       4         raise TypeError("Both Arguments must be numbers.")
#       5     return x+y
#       6 try:
#       7     print(add_numbers("10",5))
# ----> 8 except TypeError as e:
#       9     print("Error :",e)
#
# Cell In[12], line 3, in add_numbers(x, y)
#       2 def add_numbers(x,y):
# ----> 3     if not isstance(x,(int,float)) or not isinstance(y,(int,float)):
#       4         raise TypeError("Both Arguments must be numbers.")
#       5     return x+y
#
# NameError: name 'isstance' is not defined

# %%
#8. Using else with try-except
try:
    num =

# %%
#9. Nested try blocks
try:
    a = int(input("Enter a number :"))
    try:
        b = int(input("Enter another number :"))
        print("Result :" ,a/b)
    except ZeroDivisionError:
        print("Can not Divide by zero.")
except ValueError:
    print("Invalid inputs . Only integers are allowed")
# Out:
# Result : 0.35714285714285715

# %%
#10. Re-raising Exception
def divide(a,b):
    try:
        return a/b
    except ZeroDivisionError as e:
        raise
try:
    divide(10,0)
except ZeroDivisionError:
    print("Handled the re-raised exception in the outer block.")
# Out:
# Handled the re-raised exception in the outer block.
