# %% [markdown]
# // 25AIML060 //
# NIYATI RAIYANI //
# AIUC202_DATA ANALYSIS WITH PYTHON //
# CSPIT-AIML //
# BATCH-C //

# %% [markdown]
# Printing Strings

# %%
print("Hello world!")

# %%
print("'python class'")

# %%
print("Sam's class")

# %%
print("'Sam's class'")

# %% [markdown]
# Raw String

# %%
print(r'c:\Users\Sam\Desktop\pythonclass')

# %% [markdown]
# Multi-line String

# %%
print('''
hello sir 
good morning
i am student of python class
''')

# %%
print('''
hello sir,\
good morning,\
i am student of python class,\
''')

# %% [markdown]
# String Concatation

# %%
age = input("age: ")
"Your age is " + age

# %%
'5'+'5'

# %%
3*4

# %%
'A car '+'and'+' A truck'

# %% [markdown]
# Repetition(*)

# %%
print(3 * 'A car \n' + 5 * 'A truck \n')

# %% [markdown]
# format()

# %%
print("Sammy is {} and {} boy. He loves to {} games {}".format('a good', 'a naughty', 'play', 'very much'))

# %%
print("Sammy completed {0:.10f} percent of assignment".format(75.1234589))

# %%
print("Sammy completed {0:0.0f} percent of assignment".format(75.1234589))

# %% [markdown]
# Indexing

# %%
a="knights of round table"
a[5]

# %%
a="knights of round table"
a[1:6]

# %%
a="knights of round table"
a[::2]

# %% [markdown]
# Slicing

# %%
a="knights of round table"
a[-22:-15]

# %%
a="knights of round table"
a[-22::2]

# %% [markdown]
# Reverse

# %%
a="knights of round table"
a[::-1]

# %%
a=int(input("enter number 1"))
b=int(input("enter number 2"))
print("addition:",a+b)

# %%
a = 5
b = 15
c = a+b
print("addition of " +str(b) + " is " + str(c))

# %%
print('addition of {} and {} is {}'.format(a,b,c))

# %%
print('Samay is {}'.format(5))

# %%
a = 0
b = 0
a = int(input('Value 1 no is '))
b = int(input('Value 2 no is '))
print('Simple adding ')
c=a+b
print('Result of {} + {} = {}'.format(a,b,c))

# %%
string = "Hello world"

# %% [markdown]
# Indexing

# %%
string[1]

# %%
string = "Python"
string = string[:3] + "o" + string[4:]
print(string)

# %% [markdown]
# slicing

# %%
string[3:8]

# %%
string[::3]

# %%
string = 'Hello world'
string[-10 :: -6]
