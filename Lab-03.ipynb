# %% [markdown]
# // 25AIML060 //
# NIYATI RAIYANI //
# AIUC202_DATA ANALYSIS WITH PYTHON //
# CSPIT-AIML //
# BATCH-C //

# %% [markdown]
# Python Language Semantics

# %% [markdown]
# Indentation

# %% [markdown]
# Variables and Assignments

# %%
pi = 3
radius = 12
area = pi * (radius ** 2)

# %%
area
# Out:
# 432

# %%
radius = 14
area
# Out:
# 432

# %%
pi = 3
radius = 14
area = pi * (radius ** 2)
area
# Out:
# 588
