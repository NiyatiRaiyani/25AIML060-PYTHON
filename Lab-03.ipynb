# %% [markdown]
# // 25AIML060 //
# NIYATI RAIYANI //
# AIUC202_DATA ANALYSIS WITH PYTHON //
# CSPIT-AIML //
# BATCH-C //

# %% [markdown]
# Python Language Semantics

# %% [markdown]
# Indentation

# %% [markdown]
# Variables and Assignments

# %%
pi = 3
radius = 12
area = pi * (radius ** 2)

# %%
area
# Out:
# 432

# %%
radius = 14
area
# Out:
# 432

# %%
pi = 3
radius = 14
area = pi * (radius ** 2)
area
# Out:
# 588

# %% [markdown]
# Dynamic References & Strong Type

# %%
a=2 ; b=4.5

# %%
isinstance(a,(float))
# Out:
# False

# %%
isinstance(a,(int,float))
# Out:
# True

# %% [markdown]
# Attributes and Methods

# %% [markdown]
# Duck Typing

# %% [markdown]
# __account__  "Magic Method"

# %%
s = 'Niyati'
f = 5

# %%
for i in s :
    print(i)
# Out:
# N
# i
# y
# a
# t
# i

# %%
for i in [f]:
    print(i)
# Out:
# 5

# %%
s = 'Niyati'
f = 567

# %%
for i in s :
    print(i)
# Out:
# N
# i
# y
# a
# t
# i

# %%
s = 'Niyati'
f = [5,6,7]

# %%
for i in s :
    print(i)
# Out:
# N
# i
# y
# a
# t
# i

# %% [markdown]
# Import
