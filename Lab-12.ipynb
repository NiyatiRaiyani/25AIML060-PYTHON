# %% [markdown]
# **// 25AIML060 //
# NIYATI RAIYANI //
# AIUC202_DATA ANALYSIS WITH PYTHON //
# CSPIT-AIML //
# BATCH-C // **

# %% [markdown]
# **Anonymous (lambda) function **

# %%
x = lambda a : a + 10

# %%
print(x(3))
# Out:
# 13

# %% [markdown]
# **use of lambda function with filter()**

# %%
my_list = [1,2,5,6,7,8,9,4]

# %%
new_list = list(filter(lambda x :(x%2==0),my_list))

# %%
print(new_list)
# Out:
# [2, 6, 8, 4]

# %% [markdown]
# **use of lambda function with map()**

# %%
my_list = [1, 2, 5, 6, 7, 8, 9, 4]
new_list = list(map(lambda x: x * 2, my_list))
print(new_list)
# Out:
# [2, 4, 10, 12, 14, 16, 18, 8]

# %%
names = ["niyati", "priya", "krina"]
result = map(lambda name: name.upper(), names)
print(list(result))
# Out:
# ['NIYATI', 'PRIYA', 'KRINA']

# %% [markdown]
# **1. names = ["niyati", "riya", "krina", "mahi"]
# Filter the names starting with R**

# %%
names = ["niyati", "riya", "krina", "mahi"]
result = list(filter(lambda name: name.startswith("r"), names))
print(result)
# Out:
# ['riya']

# %% [markdown]
# **try Except block**

# %%
def try_float(x):
    try:
        return float(x)
    except(TypeError , ValueError):
        return x

# %%
try_float((1,2))
# Out:
# (1, 2)
