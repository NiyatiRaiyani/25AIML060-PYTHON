# %% [markdown]
# **// 25AIML060 //
# NIYATI RAIYANI //
# AIUC202_DATA ANALYSIS WITH PYTHON //
# CSPIT-AIML //
# BATCH-C // **

# %% [markdown]
# **List Comprehension**

# %%
strings =

# %% [markdown]
# **Dict and set Comprehension**

# %%
uniqueLength

# %% [markdown]
# **List Comprehension**
