# %% [markdown]
# **// 25AIML060 //
# NIYATI RAIYANI //
# AIUC202_DATA ANALYSIS WITH PYTHON //
# CSPIT-AIML //
# BATCH-C // **

# %%
import pandas as pd
data = {'colors': ['red', 'blue', 'green', 'yellow', 'black'],
        'items': ['ball', 'pen', 'pencil', 'eraser', 'sharpener'],
        'price': [2000, 1000, 3000, 5000, 4000]}
frame = pd.DataFrame(data)
frame
# Out:
#    colors      items  price
# 0     red       ball   2000
# 1    blue        pen   1000
# 2   green     pencil   3000
# 3  yellow     eraser   5000
# 4   black  sharpener   4000

# %%
frame['new'] = 12
frame
# Out:
#    colors      items  price  new
# 0     red       ball   2000   12
# 1    blue        pen   1000   12
# 2   green     pencil   3000   12
# 3  yellow     eraser   5000   12
# 4   black  sharpener   4000   12

# %%
frame['new'] = [12,14,85,96,78]
frame
# Out:
#    colors      items  price  new
# 0     red       ball   2000   12
# 1    blue        pen   1000   14
# 2   green     pencil   3000   85
# 3  yellow     eraser   5000   96
# 4   black  sharpener   4000   78

# %%
import numpy as np
ser = pd.Series(np.arange(5))
ser
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
frame ['new'] = ser
frame
# Out:
#    colors      items  price  new
# 0     red       ball   2000    0
# 1    blue        pen   1000    1
# 2   green     pencil   3000    2
# 3  yellow     eraser   5000    3
# 4   black  sharpener   4000    4

# %%
frame['price'][2]=1000
frame
# Out:
# C:\Users\hppc\AppData\Local\Temp\ipykernel_9488\1041182878.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   frame['price'][2]=1000
#    colors      items  price  new
# 0     red       ball   2000    0
# 1    blue        pen   1000    1
# 2   green     pencil   3000    2
# 3  yellow     eraser   5000    3
# 4   black  sharpener   4000    4
