# %% [markdown]
# **// 25AIML060 //
# NIYATI RAIYANI //
# AIUC202_DATA ANALYSIS WITH PYTHON //
# CSPIT-AIML //
# BATCH-C // **

# %% [markdown]
# **File Handling - Writing**

# %%
f = open("student.txt", "a")
f.write("New Content\n")
f.close()

# %%
f = open("myfile.txt", "w")
f.write("This is my file.")
f.close()
